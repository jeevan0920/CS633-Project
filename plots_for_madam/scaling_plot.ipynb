# %%
import pandas as pd

# %%
ppn_8 = pd.read_csv("./AllGatherV_Isend_ppn_8")

# %%
ppn_4 = pd.read_csv("./All_Gather_V_Isend_ppn_4")

# %%
ppn_8.index = ppn_8["Number_processes"]

# %%
(ppn_8.iloc[:,1:]).plot(title="scaling_plot_AllGatherV_with_ppn_8")

# %%
ppn_4.index = ppn_4["Number_processes"]

# %%
(ppn_4.iloc[:,1:]).plot(title="scaling_plot_AllGatherV_with_pp_n4")
